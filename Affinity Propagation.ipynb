# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Mall_Customers.csv")

# %%
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
X=dataset.iloc[:,3:5].values

# %%
X
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
from sklearn.cluster import AffinityPropagation
X,mb= make_blobs(n_samples = 100, centers = [(11,11), (20,20)], n_features =50 , center_box=(1, 2),random_state = 45)
cluster = AffinityPropagation(max_iter=200)
cluster.fit(X)
cluster_centers_ = cluster.cluster_centers_
n_clusters_ = len(cluster_centers_)
y_pred=cluster.predict(X)
colors = plt.cm.viridis(np.linspace(0, 1, n_clusters_))
colors = y_pred
plt.scatter(X[:, 0], X[:, 1], c=y_pred, marker="o", picker=True)
plt.title(f'Estimated number of clusters = {n_clusters_}')
plt.xlabel('clusters')
plt.ylabel('distance')
colors = plt.cm.viridis(np.linspace(0, 1, n_clusters_))
for k, col in zip(range(n_clusters_), colors):
    class_members = y_pred == k
    cluster_center = cluster_centers_[k]
    plt.scatter(
        X[class_members, 0], X[class_members, 1], color=col, marker="."
    )
    plt.scatter(
        cluster_center[0], cluster_center[1], s=14, color=col, marker="o"
    )
    for x in X[class_members]:
        plt.plot(
            [cluster_center[0], x[0]], [cluster_center[1], x[1]], color=col
        )

plt.show()

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import AffinityPropagation
X, _ = make_blobs(n_samples=100, centers=3, n_features=2, random_state=0)
cluster = AffinityPropagation()
cluster.fit(X)
y_pred = cluster.labels_

# %%
supervised=dataset

# %%
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
supervised["return_customer"]=cluster

# %%
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#            return_customer
# 0    AffinityPropagation()
# 1    AffinityPropagation()
# ...

# %%
supervised.to_csv("clusters.csv",index=False)

# %%
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#            return_customer
# 0    AffinityPropagation()
# 1    AffinityPropagation()
# ...

# %%
cluster
# Out:
# AffinityPropagation()

# %%
y_pred
# Out:
# array([3, 1, 3, 0, 2, 3, 0, 1, 3, 1, 3, 3, 3, 3, 2, 1, 1, 3, 3, 1, 3, 0,
#        3, 2, 2, 0, 3, 1, 3, 0, 0, 1, 0, 2, 3, 2, 0, 1, 3, 2, 0, 0, 1, 3,
#        1, 1, 3, 0, 0, 3, 3, 1, 1, 0, 3, 0, 0, 0, 0, 2, 2, 2, 2, 2, 0, 1,
#        1, 1, 1, 3, 1, 0, 1, 2, 3, 2, 1, 2, 2, 2, 0, 0, 3, 0, 2, 2, 3, 0,
#        0, 3, 2, 1, 2, 1, 0, 1, 1, 3, 3, 2], dtype=int64)

# %%
supervised.columns
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)', 'return_customer'],
#       dtype='object')

# %%
import seaborn as sns
sea=sns.lmplot(data=supervised,x=supervised.columns[3],y=supervised.columns[4],hue=supervised.columns[5],
               fit_reg=False,legend=True,legend_out=True)
plt.show()
# Out:
# C:\Users\ragus\anaconda3\Lib\site-packages\seaborn\regression.py:582: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
